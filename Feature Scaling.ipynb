# %% [markdown]
# Feature scaling is a technique used in machine learning to normalize the range of features within a dataset.<br>
# Feature scaling does not change the shape of the distribution of the data

# %% [markdown]
# ### Why feature scaling is required?
#
# - Smoother Convergence: Many machine learning algorithms, particularly those that use gradient descent to optimize<br>
#   their parameters, take small steps in the direction that minimizes the error. The size of these steps is<br> often determined by the feature values. Having features on a similar scale will help the gradient descent converge more quickly<br> towards the minima.
# - Distance-based algorithms: Distance-based algorithms like KNN, K-means, and SVM are most affected by the range<br> of features. This is because behind the scenes they are using distances between data points to determine their similarity and hence<br> perform the task at hand.

# %% [markdown]
# #### Algorithms requiring the use of feature scaling-
# 1. Linear Regression
# 2. Logistic Regression
# 3. KNN
# 4. Clustering algorithms(K-means,Hierarchical etc)
# 5. K-Nearest Neighbors (KNN)
# 6. SVM
#
# #### Algorithms which do not require the use of feature scaling -
# 1. Decision Trees
# 2. Random Forest
# 3. Boosting Techniques(Gradient Boost, AdaBoost, XGBoost)
# 4. Naive Bayes

# %% [markdown]
# #### Feature Scaling Techniques
# 1. Standardization
# 2. Normalization

# %% [markdown]
# ### Standardization

# %% [markdown]
# The formula used for standardization is :<br>
# **z = (x - u) / s**  , where x- data point ,u-  mean, s - standard deviation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("C:\\Users\\himan\\OneDrive\\Desktop\\csv\\Machine Learning\\BostonHousing.csv")
df.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87   NaN  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87   NaN  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# ...

# %%
df.shape
# Out:
# (506, 14)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_standardized = scaler.fit_transform(df.drop(columns=["CHAS"]))
df_standardized = pd.DataFrame(df_standardized,columns=df.drop(columns=["CHAS"]).columns)

# %%
sns.histplot(data=df,x="LSTAT",kde=True)
# Out:
# <Axes: xlabel='LSTAT', ylabel='Count'>

# %%
sns.histplot(x=df_standardized.LSTAT,kde=True)
# Out:
# <Axes: xlabel='LSTAT', ylabel='Count'>

# %%
sns.histplot(x=df.MEDV,kde=True)
# Out:
# <Axes: xlabel='MEDV', ylabel='Count'>

# %%
sns.histplot(x=df_standardized.MEDV,kde=True)
# Out:
# <Axes: xlabel='MEDV', ylabel='Count'>

# %% [markdown]
# **Note**: Standardization does not change the distribution of your dataset, rather scales the data with a mean of zero and
# standard deviation 1

# %% [markdown]
# #### Normalization

# %% [markdown]
# Normalization, also sometimes referred to as min-max scaling, is a technique for scaling features in a dataset to a fixed range, between 0 and 1.

# %% [markdown]
# ![image.png](attachment:c9fbd19a-452e-4fae-8b0a-486f01b53af0.png)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_normalized = scaler.fit_transform(df.drop(columns=["CHAS"]))
df_normalized=  pd.DataFrame(df_normalized,columns=df.drop(columns=["CHAS"]).columns)

# %%
sns.histplot(x=df_normalized.LSTAT,kde=True)
# Out:
# <Axes: xlabel='LSTAT', ylabel='Count'>

# %% [markdown]
# When to use Min-Max Scaler vs Standardization?

# %% [markdown]
# - Though there is no rule of thumb on using normalization or standardization, *it has been observed that in most of the machine learning use-cases standardization performs well.*
# - *Normalization is often used in deep learning techniques.*
# - You can try using both normalization and standardization and compare the performance of your model.

# %% [markdown]
# ### Assignment
# Apply standardization and normalization to any 5 features of the load_wine() dataset in sklearn

# %%
from sklearn.datasets import load_wine
import pandas as pd
print(load_wine().DESCR)
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 178
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- Alcohol
#  		- Malic acid
#  		- Ash
# 		- Alcalinity of ash
#  		- Magnesium
# 		- Total phenols
#  		- Flavanoids
#  		- Nonflavanoid phenols
#  		- Proanthocyanins
# 		- Color intensity
#  		- Hue
#  		- OD280/OD315 of diluted wines
#  		- Proline
#
#     - class:
#             - class_0
#             - class_1
#             - class_2
#
#     :Summary Statistics:
#
#     ============================= ==== ===== ======= =====
#                                    Min   Max   Mean     SD
#     ============================= ==== ===== ======= =====
#     Alcohol:                      11.0  14.8    13.0   0.8
#     Malic Acid:                   0.74  5.80    2.34  1.12
#     Ash:                          1.36  3.23    2.36  0.27
# ...

# %%
help(plt.boxplot)
# Out:
# Help on function boxplot in module matplotlib.pyplot:
#
# boxplot(x, notch=None, sym=None, vert=None, whis=None, positions=None, widths=None, patch_artist=None, bootstrap=None, usermedians=None, conf_intervals=None, meanline=None, showmeans=None, showcaps=None, showbox=None, showfliers=None, boxprops=None, labels=None, flierprops=None, medianprops=None, meanprops=None, capprops=None, whiskerprops=None, manage_ticks=True, autorange=False, zorder=None, capwidths=None, *, data=None)
#     Draw a box and whisker plot.
#
#     The box extends from the first quartile (Q1) to the third
#     quartile (Q3) of the data, with a line at the median.  The
#     whiskers extend from the box by 1.5x the inter-quartile range
#     (IQR).  Flier points are those past the end of the whiskers.
#     See https://en.wikipedia.org/wiki/Box_plot for reference.
#
#     .. code-block:: none
#
#               Q1-1.5IQR   Q1   median  Q3   Q3+1.5IQR
#                            |-----:-----|
# ...

# %%
df1 = pd.DataFrame(load_wine().data,columns=load_wine().feature_names)
df1
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
sns.histplot(data=df1,x="alcohol",kde=True)
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %%
df1.isnull().sum()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# dtype: int64

# %%
plt.boxplot(df1)
plt.title('Boxplot of Sample Data')
plt.ylabel('Values')
plt.show()

# %%
df1.shape
# Out:
# (178, 13)

# %%
df = pd.DataFrame(df1)
corr_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
import pandas as pd


df = pd.DataFrame(df1)

# Calculate quartiles
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)

# Calculate IQR (Interquartile Range)
IQR = Q3 - Q1

# Identify outliers
outliers = ((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)

# Print rows containing outliers
print("Rows containing outliers:")
print(df[outliers])
# Out:
# Rows containing outliers:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 25     13.05        2.05  3.22               25.0      124.0           2.63
# 59     12.37        0.94  1.36               10.6       88.0           1.98
# 69     12.21        1.19  1.75               16.8      151.0           1.85
# 73     12.99        1.67  2.60               30.0      139.0           3.30
# 78     12.33        0.99  1.95               14.8      136.0           1.90
# 95     12.47        1.52  2.20               19.0      162.0           2.50
# 110    11.46        3.74  1.82               19.5      107.0           3.18
# 115    11.03        1.51  2.20               21.5       85.0           2.46
# 121    11.56        2.05  3.23               28.5      119.0           3.18
# 123    13.05        5.80  2.13               21.5       86.0           2.62
# 127    11.79        2.13  2.78               28.5       92.0           2.13
# ...

# %%
from sklearn.preprocessing import StandardScaler
df = pd.DataFrame(df1)
df.dropna(inplace=True)
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_data, columns=df.columns)
scaled_df
# Out:
#       alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# 0    1.518613   -0.562250  0.232053          -1.169593   1.913905
# 1    0.246290   -0.499413 -0.827996          -2.490847   0.018145
# 2    0.196879    0.021231  1.109334          -0.268738   0.088358
# 3    1.691550   -0.346811  0.487926          -0.809251   0.930918
# 4    0.295700    0.227694  1.840403           0.451946   1.281985
# ..        ...         ...       ...                ...        ...
# 173  0.876275    2.974543  0.305159           0.301803  -0.332922
# 174  0.493343    1.412609  0.414820           1.052516   0.158572
# 175  0.332758    1.744744 -0.389355           0.151661   1.422412
# 176  0.209232    0.227694  0.012732           0.151661   1.422412
# 177  1.395086    1.583165  1.365208           1.502943  -0.262708
#
#      total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0         0.808997    1.034819             -0.659563         1.224884
# ...
